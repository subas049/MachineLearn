# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\Trkec\\Downloads\\WK3-20230306T144615Z-001\\WK3'

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'combined.csv',
#  'combined.xlsx',
#  'Matplotlib.ipynb',
#  'Pandas.ipynb',
#  'titles.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
df = pd.read_csv('titles.csv')

# %%
df
# Out:
#                                 title  year
# 0                           The Other  2016
# 1                         Hideg napok  1966
# 2                         Shantav den  2004
# 3                   School for Danger  1947
# 4                   Wanted: A Husband  1919
# ...                               ...   ...
# 228526                     Los Cartel  2018
# 228527  Twee jongens en een oude auto  1969
# 228528            Wanita tetap wanita  2013
# 228529                       Triangle  2019
# 228530                       Burnt In  1920
#
# [228531 rows x 2 columns]

# %%
tips = sns.load_dataset('tips')

# %%
# average tip of a female and male
tips.groupby(['sex'])['tip'].mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['sex']=='Female'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243     True
# Name: sex, Length: 244, dtype: bool

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
(tips['sex'] == 'Female') & (tips['smoker'] == 'Yes')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
tips[(tips['sex'] == 'Male') | (tips['smoker'] == 'yes')].shape
# Out:
# (157, 7)

# %%
pd.crosstab(tips['sex'], tips['smoker'])
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips[tips['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(tips['total_bill'], tips['tip'], 'o')
plt.xlabel('total_bill_spent')
plt.ylabel('tips amount')
plt.title('Total Bills Vs Tip ')
# Out:
# Text(0.5, 1.0, 'Total Bills Vs Tip ')

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\Trkec\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.jointplot(tips['total_bill'], tips['tip'], kind = 'reg')
# Out:
# C:\Users\Trkec\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(tips, hue = 'sex')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
Multivariate analysis -- Analyzing the multiple variable and it's relationship. -- pairplot -- ML
Bivariate Analysys - two variable analysis -- scatter plot, pairplot or joint plot
Univariate analysis - analyzing the single variable -- count plot, distplot, hist

# %%
sns.countplot(tips['sex'])
# Out:
# C:\Users\Trkec\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>
